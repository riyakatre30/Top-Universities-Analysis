# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df = pd.read_csv("../Datasets/Top_University.csv")
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %% [markdown]
# # Data Preparation

# %%
df.dtypes
# Out:
# world_rank                int64
# institution              object
# country                  object
# national_rank             int64
# quality_of_education      int64
# alumni_employment         int64
# quality_of_faculty        int64
# publications              int64
# influence                 int64
# citations                 int64
# broad_impact            float64
# patents                   int64
# score                   float64
# year                      int64
# dtype: object

# %%
df.isnull().sum()
# Out:
# world_rank                0
# institution               0
# country                   0
# national_rank             0
# quality_of_education      0
# alumni_employment         0
# quality_of_faculty        0
# publications              0
# influence                 0
# citations                 0
# broad_impact            200
# patents                   0
# score                     0
# year                      0
# dtype: int64

# %%
df.broad_impact = df.broad_impact.fillna(0)

# %%
df
# Out:
#       world_rank                            institution         country  \
# 0              1                     Harvard University             USA
# 1              2  Massachusetts Institute of Technology             USA
# 2              3                    Stanford University             USA
# 3              4                University of Cambridge  United Kingdom
# 4              5     California Institute of Technology             USA
# ...          ...                                    ...             ...
# 2195         996              University of the Algarve        Portugal
# 2196         997                  Alexandria University           Egypt
# 2197         998            Federal University of Ceará          Brazil
# 2198         999                 University of A Coruña           Spain
# 2199        1000        China Pharmaceutical University           China
#
#       national_rank  quality_of_education  alumni_employment  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
df.describe()
# Out:
#         world_rank  national_rank  quality_of_education  alumni_employment  \
# count  2200.000000    2200.000000           2200.000000        2200.000000
# mean    459.590909      40.278182            275.100455         357.116818
# std     304.320363      51.740870            121.935100         186.779252
# min       1.000000       1.000000              1.000000           1.000000
# 25%     175.750000       6.000000            175.750000         175.750000
# 50%     450.500000      21.000000            355.000000         450.500000
# 75%     725.250000      49.000000            367.000000         478.000000
# max    1000.000000     229.000000            367.000000         567.000000
#
#        quality_of_faculty  publications    influence    citations  \
# count         2200.000000   2200.000000  2200.000000  2200.000000
# mean           178.888182    459.908636   459.797727   413.417273
# std             64.050885    303.760352   303.331822   264.366549
# ...

# %%
df.groupby('country')['score'].sum()
# Out:
# country
# Argentina                 312.71
# Australia                2657.88
# Austria                  1083.35
# Belgium                   940.22
# Brazil                   1612.12
# Bulgaria                   88.67
# Canada                   3409.87
# Chile                     358.14
# China                    7513.76
# Colombia                  177.73
# Croatia                    89.54
# Cyprus                     88.42
# Czech Republic            447.61
# Denmark                   573.29
# Egypt                     353.84
# Estonia                    89.62
# Finland                   910.63
# France                   5054.04
# Germany                  5337.51
# Greece                    627.96
# Hong Kong                 555.54
# Hungary                   535.24
# Iceland                    89.96
# India                    1386.11
# Iran                      708.32
# Ireland                   723.76
# Israel                   1158.39
# Italy                    4363.22
# ...

# %%
df.groupby('institution')['score'].sum()
# Out:
# institution
# AGH University of Science and Technology     88.97
# Aalborg University                           89.42
# Aalto University                             90.68
# Aarhus University                            99.82
# Aberystwyth University                       88.75
#                                              ...
# École centrale de Lyon                       44.15
# École normale supérieure - Paris            215.32
# École normale supérieure de Cachan           44.33
# École normale supérieure de Lyon             90.12
# Örebro University                            89.14
# Name: score, Length: 1024, dtype: float64

# %%
df.groupby('country')['score'].mean()
# Out:
# country
# Argentina               44.672857
# Australia               45.825517
# Austria                 45.139583
# Belgium                 47.011000
# Brazil                  44.781111
# Bulgaria                44.335000
# Canada                  47.359306
# Chile                   44.767500
# China                   44.992575
# Colombia                44.432500
# Croatia                 44.770000
# Cyprus                  44.210000
# Czech Republic          44.761000
# Denmark                 47.774167
# Egypt                   44.230000
# Estonia                 44.810000
# Finland                 45.531500
# France                  46.367339
# Germany                 46.413130
# Greece                  44.854286
# Hong Kong               46.295000
# Hungary                 44.603333
# Iceland                 44.980000
# India                   44.713226
# Iran                    44.270000
# Ireland                 45.235000
# Israel                  52.654091
# ...

# %%
df.groupby('institution')['score'].mean()
# Out:
# institution
# AGH University of Science and Technology    44.485
# Aalborg University                          44.710
# Aalto University                            45.340
# Aarhus University                           49.910
# Aberystwyth University                      44.375
#                                              ...
# École centrale de Lyon                      44.150
# École normale supérieure - Paris            53.830
# École normale supérieure de Cachan          44.330
# École normale supérieure de Lyon            45.060
# Örebro University                           44.570
# Name: score, Length: 1024, dtype: float64

# %%
sb.histplot(df.score)
plt.show()

# %%
sb.boxplot(df.score)
plt.show()

# %% [markdown]
# # Top Universities Analysis

# %%
y = df[df.year == 2014]
y.sort_values('world_rank').head(10)
# Out:
#      world_rank                            institution         country  \
# 200           1                     Harvard University             USA
# 201           2                    Stanford University             USA
# 202           3  Massachusetts Institute of Technology             USA
# 203           4                University of Cambridge  United Kingdom
# 204           5                   University of Oxford  United Kingdom
# 205           6                    Columbia University             USA
# 206           7     University of California, Berkeley             USA
# 207           8                  University of Chicago             USA
# 208           9                   Princeton University             USA
# 209          10                        Yale University             USA
#
#      national_rank  quality_of_education  alumni_employment  \
# 200              1                     1                  1
# 201              2                    11                  2
# ...

# %%
df.groupby('institution')[['world_rank','national_rank','score']].count().nsmallest(10,'world_rank')
# Out:
#                                          world_rank  national_rank  score
# institution
# Babeș-Bolyai University                           1              1      1
# Beijing Jiaotong University                       1              1      1
# Chemnitz University of Technology                 1              1      1
# China University of Geosciences (Wuhan)           1              1      1
# Gachon University                                 1              1      1
# Guangxi University                                1              1      1
# Harbin Engineering University                     1              1      1
# Harbin Medical University                         1              1      1
# Hefei University of Technology                    1              1      1
# Henan Normal University                           1              1      1

# %% [markdown]
# # Country Performance

# %%
a = df.groupby('institution')[['world_rank']].value_counts().head(100)
a
# Out:
# institution                               world_rank
# AGH University of Science and Technology  653           1
#                                           782           1
# Aalborg University                        565           1
#                                           593           1
# Aalto University                          392           1
#                                                        ..
# Brigham Young University                  403           1
#                                           415           1
# Brock University                          861           1
#                                           884           1
# Brown University                          66            1
# Name: count, Length: 100, dtype: int64

# %%
print(df.institution.unique())
inst = input("Enter Institution Name : ")
i = df[df.institution == inst]

sb.countplot(x = i.institution)
plt.show()
# Out:
# ['Harvard University' 'Massachusetts Institute of Technology'
#  'Stanford University' ... 'Babeș-Bolyai University'
#  'Henan Normal University' 'Southwest Jiaotong University']
# Enter Institution Name :  Harvard University

# %%
df.groupby('country')['score'].mean()
# Out:
# country
# Argentina               44.672857
# Australia               45.825517
# Austria                 45.139583
# Belgium                 47.011000
# Brazil                  44.781111
# Bulgaria                44.335000
# Canada                  47.359306
# Chile                   44.767500
# China                   44.992575
# Colombia                44.432500
# Croatia                 44.770000
# Cyprus                  44.210000
# Czech Republic          44.761000
# Denmark                 47.774167
# Egypt                   44.230000
# Estonia                 44.810000
# Finland                 45.531500
# France                  46.367339
# Germany                 46.413130
# Greece                  44.854286
# Hong Kong               46.295000
# Hungary                 44.603333
# Iceland                 44.980000
# India                   44.713226
# Iran                    44.270000
# Ireland                 45.235000
# Israel                  52.654091
# ...

# %% [markdown]
# # Factor Analysis

# %%
b = df.corr(numeric_only=True)
b
# Out:
#                       world_rank  national_rank  quality_of_education  \
# world_rank              1.000000       0.238553              0.676166
# national_rank           0.238553       1.000000              0.211975
# quality_of_education    0.676166       0.211975              1.000000
# alumni_employment       0.668529       0.135342              0.606421
# quality_of_faculty      0.663864       0.222833              0.786181
# publications            0.923037       0.326857              0.624657
# influence               0.895871       0.161086              0.645641
# citations               0.856573       0.186797              0.630455
# broad_impact            0.953006       0.214437              0.637312
# patents                 0.698214       0.159440              0.528120
# score                  -0.549098      -0.199756             -0.600541
# year                    0.320844       0.102951              0.427732
#
# ...

# %%
plt.scatter(df.citations,df.score)
plt.show()

# %%
plt.scatter(df.quality_of_education,df.alumni_employment,df.quality_of_faculty)
plt.show()

# %% [markdown]
# # Trend Analysis

# %%
df.groupby('institution')['year'].mean()
# Out:
# institution
# AGH University of Science and Technology    2014.5
# Aalborg University                          2014.5
# Aalto University                            2014.5
# Aarhus University                           2014.5
# Aberystwyth University                      2014.5
#                                              ...
# École centrale de Lyon                      2015.0
# École normale supérieure - Paris            2013.5
# École normale supérieure de Cachan          2015.0
# École normale supérieure de Lyon            2014.5
# Örebro University                           2014.5
# Name: year, Length: 1024, dtype: float64

# %%
pd.pivot_table(df,index='institution',columns='year',values='score',aggfunc='sum',margins=True)
# Out:
# year                                         2012     2013      2014  \
# institution
# AGH University of Science and Technology      NaN      NaN     44.71
# Aalborg University                            NaN      NaN     44.83
# Aalto University                              NaN      NaN     45.58
# Aarhus University                             NaN      NaN     50.17
# Aberystwyth University                        NaN      NaN     44.53
# ...                                           ...      ...       ...
# École normale supérieure - Paris            49.10    47.70     59.72
# École normale supérieure de Cachan            NaN      NaN       NaN
# École normale supérieure de Lyon              NaN      NaN     45.25
# Örebro University                             NaN      NaN     44.70
# All                                       5494.09  5527.12  47271.41
#
# year                                          2015        All
# institution
# ...

# %%
pd = pd.pivot_table(df,index='institution',columns='year',values='world_rank',aggfunc='sum',margins=True)
pd
# Out:
# year                                        2012    2013      2014      2015  \
# institution
# AGH University of Science and Technology     NaN     NaN     653.0     782.0
# Aalborg University                           NaN     NaN     593.0     565.0
# Aalto University                             NaN     NaN     392.0     421.0
# Aarhus University                            NaN     NaN     119.0     122.0
# Aberystwyth University                       NaN     NaN     800.0     814.0
# ...                                          ...     ...       ...       ...
# École normale supérieure - Paris            54.0    64.0      35.0      37.0
# École normale supérieure de Cachan           NaN     NaN       NaN     721.0
# École normale supérieure de Lyon             NaN     NaN     462.0     471.0
# Örebro University                            NaN     NaN     656.0     639.0
# All                                       5050.0  5050.0  500500.0  500500.0
#
# ...

# %%
plt.figure(figsize =[10,5])
sb.heatmap(b)
plt.show()
